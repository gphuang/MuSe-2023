# %%
import os, sys
import librosa
import pandas as pd
import numpy as np

# %%
# config
sys.path.append('/scratch/work/huangg5/muse/MuSe-2023')
from config import BASE_PATH, TASKS, PATH_TO_FEATURES, PATH_TO_LABELS, PERSONALISATION_DIMS
# BASE_PATH = '/scratch/elec/puhe/c/muse_2023/' 
# PATH_TO_FEATURES = os.path.join(BASE_PATH, 'c3_muse_personalisation/feature_segments')

# %%
print(TASKS)
print(PERSONALISATION_DIMS)
print(PATH_TO_FEATURES)
task = TASKS[2]
# Out:
# ['mimic', 'humor', 'personalisation']
# ['physio-arousal', 'valence', 'BPM_normalized', 'resp_normalized', 'ECG_normalized']
# {'mimic': '/scratch/elec/puhe/c/muse_2023/c1_muse_mimic/features', 'humor': '/scratch/elec/puhe/c/muse_2023/c2_muse_humor/feature_segments', 'personalisation': '/scratch/elec/puhe/c/muse_2023/c3_muse_personalisation/feature_segments'}

# %% [markdown]
# ### Audio

# %%
data_name = '/scratch/elec/puhe/c/muse_2023/c3_muse_personalisation/raw_data/audio_wav/1.wav'
data, _ = librosa.load(data_name, dtype=np.float32)
print(data.shape)
# Out:
# (6593127,)

# %%
fname = os.path.join(PATH_TO_FEATURES[task], 'w2v-msp/10.csv')
df = pd.read_csv(fname)
print(df.shape)
# Out:
# (588, 1026)

# %% [markdown]
# ### Biosignals

# %%
fname = os.path.join(PATH_TO_LABELS[task], 'physio-arousal/10.csv')
df = pd.read_csv(fname)
print(df.shape)
# Out:
# (588, 3)

# %%
print(df.head(3))
df['value'].plot(title=affect)
# Out:
#    timestamp  subject_id   value
# 0        500          10  0.1577
# 1       1000          10  0.1691
# 2       1500          10  0.1793
# <Axes: title={'center': 'physio-arousal'}>

# %%
bio='resp'
fname = os.path.join(PATH_TO_FEATURES[task], 'resp_raw/10.csv')
df = pd.read_csv(fname)
df[bio][:2000,].plot(title=bio)
# Out:
# <Axes: title={'center': 'resp'}>

# %% [markdown]
# ### Time Series Precition on Valence
